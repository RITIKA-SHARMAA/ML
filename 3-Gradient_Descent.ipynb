# %% [markdown]
# <a href="https://colab.research.google.com/github/RITIKA-SHARMAA/ML/blob/main/3-Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {
    "name": ["david", "laura", "sanjay", "wei", "jeff", "aamir", "venkat", "virat", "arthur", "paul"],
    "math": [92, 56, 88, 70, 80, 49, 65, 35, 66, 67],
    "cs": [98, 68, 81, 80, 83, 52, 66, 30, 68, 73]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x = np.array(data["math"])
y = np.array(data["cs"])

print (x)
print(y)
# Out:
# [92 56 88 70 80 49 65 35 66 67]
# [98 68 81 80 83 52 66 30 68 73]

# %%
# Gradient Descent Parameters

m, b = 0, 0  # Initial slope and intercept
learning_rate = 0.01
iterations = 1000

x = (x - np.mean(x)) / np.std(x)
y = (y - np.mean(y)) / np.std(y)
#Scale the data so that its mean is 0 and standard deviation is 1. This helps prevent large gradient values.

for _ in range(iterations):
    y_predicted = m * x + b
    error = y_predicted - y
    plt.plot(x,y_predicted,color='green')

    # Calculate gradients (slopes )
    dm = (2 / len(x)) * np.sum(error * x)
    db = (2 / len(x)) * np.sum(error)

    # Update parameters
    m -= learning_rate * dm
    b -= learning_rate * db

    # Results
    # print(f"Slope (m): {m}")
    # print(f"Intercept (b): {b}")

print(f"Slope (m): {m}")
print(f"Intercept (b): {b}")

# Correlation
print(f"Equation: y = {m:.2f}x + {b:.2f}")

plt.figure(figsize=(10, 6))
plt.scatter(x_normalized, y_normalized, color='blue', label='Actual Data')  # Actual points
plt.plot(x_normalized, m * x_normalized + b, color='red', label='Predicted Line')  # Regression line
plt.title('Math vs CS Scores (Normalized)')
plt.xlabel('Math Scores (Normalized)')
plt.ylabel('CS Scores (Normalized)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Slope (m): 0.9481857110837536
# Intercept (b): -5.60107515923389e-17
# Equation: y = 0.95x + -0.00
